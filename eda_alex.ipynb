# %%
import pandas as pd

df = pd.read_excel('/afh/projects/SY-Tagging-NOT_DELETE-7b113334-385d-4e41-87b7-c77611f91817/shared/Users/ioki/ml-service_now_tagging/data/untagged/1-7-Dec-merged.xlsx')

# %%
# Rename all columns: lowercase and replace spaces with underscores
df.columns = [col.strip().lower().replace(' ', '_') for col in df.columns]

# %%
# delete all columns wiht less than 3200 entires
df = df.dropna(thresh=2300, axis=1)
df = df.drop(['updated', 'reporter','updated_by', 'status','reassignment_count','child_incidents','updated_by'], axis=1)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        number              opened priority                          service  \
# 0  INC0133168 2025-11-30 10:03:13  4 - Low         Broad- YouSeemail - Prod
# 1  INC0133171 2025-11-30 10:20:22  4 - Low  TV-Video On Demand (VOD) - PROD
# 2  INC0133177 2025-11-30 10:53:51  4 - Low                   TV -Misc- Prod
# 3  INC0133167 2025-11-30 09:47:44  4 - Low             Dawn Agent UI - PROD
# 4  INC0133169 2025-11-30 10:05:27  4 - Low             Dawn Agent UI - PROD
#
#                                                title  \
# 0  Support - YouSee mail/Issue with Mit YouSee/Ca...
# 1     Support - TV/Video on demand/Streamer or Audio
# 2                      Support - TV/Other/Bland Selv
# 3         Support - Dawn/With Customer context/Other
# 4  Support - Dawn/With Customer context/Customer ...
#
#                                          description     category  \
# 0  When the Customer tries to log in to his email...  Application
# 1  Customer experiences that when they get up at ...  Application
# 2  After the Customer got a new TV, the Customer'...  Application
# 3  It is listed as an ongoing change\n\nCategory:...  Application
# 4  The Customer has changed address, applied CPR ...  Application
#
#                         assignment_group  \
# 0                 YouSee Mail Validation
# 1  TV-Video On Demand (VOD) – Validation
# 2                   TV-Misc – Validation
# 3                      Nuuday Front Desk
# 4                         YAC-Resolution
#
#                                               impact  \
# 0  Minor - Errors affecting a group or a few cust...
# 1  Minor - Errors affecting a group or a few cust...
# 2  Minor - Errors affecting a group or a few cust...
# 3  Minor - Errors affecting a group or a few cust...
# 4  Minor - Errors affecting a group or a few cust...
#
#                                              urgency
# 0  Low - Total loss or degradation of a non-busin...
# 1  Low - Total loss or degradation of a non-busin...
# 2  Low - Total loss or degradation of a non-busin...
# 3  Low - Total loss or degradation of a non-busin...
# 4  Low - Total loss or degradation of a non-busin...
